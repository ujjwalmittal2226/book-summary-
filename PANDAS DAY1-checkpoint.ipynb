# %% [markdown]
# It has functions for analyzing, cleaning, exploring, and manipulating data.
# Pandas allows us to analyze big data and make conclusions based on statistical theories.
# Pandas can clean messy data sets, and make them readable and relevant
# Pandas is a powerful,fast open source data analysis & manipulation tools. 2 types- series, dataframe.
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
# Series is like a column, a DataFrame is the whole table

# %%
import pandas as pd
a = [1,6,2]
my_var = pd.Series(a,index = ["x","y","z"])
print(my_var)
# Out:
# x    1
# y    6
# z    2
# dtype: int64

# %% [markdown]
# In real world problem we are required labelled data for effective data analysis and  meaningful interpretation,<center><b>IMPORTING THE DATASET</n></b></center>
# read_csv(),read_excel(),read_html,read_sql().

# %%
df = pd.read_csv(r"C:\Users\ADMIN\Downloads\student-scores.csv")
print(df)
# Out:
#         id first_name last_name                                    email  \
# 0        1       Paul     Casey           paul.casey.1@gslingacademy.com
# 1        2   Danielle  Sandoval    danielle.sandoval.2@gslingacademy.com
# 2        3       Tina   Andrews         tina.andrews.3@gslingacademy.com
# 3        4       Tara     Clark           tara.clark.4@gslingacademy.com
# 4        5    Anthony    Campos       anthony.campos.5@gslingacademy.com
# ...    ...        ...       ...                                      ...
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# ...

# %%
#BAsics of DataFrames
df.head(5)
df.tail(5) #if 2 command are passed then last one is executed.
# Out:
#         id first_name last_name                                    email  \
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# 1995    male          False             2                       False
# 1996    male          False             2                       False
# 1997  female          False             5                       False
# 1998  female           True            10                        True
# 1999  female          False             5                       False
#
#       weekly_self_study_hours      career_aspiration  math_score  \
# ...

# %%
df.sample(8)
# Out:
#         id first_name last_name                                   email  \
# 350    351      Aimee     Adams       aimee.adams.351@gslingacademy.com
# 1678  1679   Patricia    Rivera  patricia.rivera.1679@gslingacademy.com
# 885    886      Bryan    Grimes      bryan.grimes.886@gslingacademy.com
# 1992  1993       John  Peterson    john.peterson.1993@gslingacademy.com
# 1129  1130       Emma     Jones       emma.jones.1130@gslingacademy.com
# 1858  1859     Johnny     Gomez     johnny.gomez.1859@gslingacademy.com
# 1217  1218     George   Francis   george.francis.1218@gslingacademy.com
# 1109  1110   Jonathan    Finley  jonathan.finley.1110@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# 350   female          False             3                       False
# 1678  female          False             3                        True
# 885     male          False             7                       False
# ...

# %%
df.info()
#It gave the information realted to variable and there data types.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          2000 non-null   int64
#  1   first_name                  2000 non-null   object
#  2   last_name                   2000 non-null   object
#  3   email                       2000 non-null   object
#  4   gender                      2000 non-null   object
#  5   part_time_job               2000 non-null   bool
#  6   absence_days                2000 non-null   int64
#  7   extracurricular_activities  2000 non-null   bool
#  8   weekly_self_study_hours     2000 non-null   int64
#  9   career_aspiration           2000 non-null   object
#  10  math_score                  2000 non-null   int64
#  11  history_score               2000 non-null   int64
#  12  physics_score               2000 non-null   int64
# ...

# %%
df.describe() #It show information related to basic statisical values of all columns of the datatset.
# Out:
#                 id  absence_days  weekly_self_study_hours   math_score  \
# count  2000.000000   2000.000000              2000.000000  2000.000000
# mean   1000.500000      3.665500                17.755500    83.452000
# std     577.494589      2.629271                12.129604    13.224906
# min       1.000000      0.000000                 0.000000    40.000000
# 25%     500.750000      2.000000                 5.000000    77.000000
# 50%    1000.500000      3.000000                18.000000    87.000000
# 75%    1500.250000      5.000000                28.000000    93.000000
# max    2000.000000     10.000000                50.000000   100.000000
#
#        history_score  physics_score  chemistry_score  biology_score  \
# count    2000.000000    2000.000000      2000.000000     2000.00000
# mean       80.332000      81.336500        79.995000       79.58150
# std        12.736046      12.539453        12.777895       13.72219
# ...

# %%
df[['absence_days','email']].head(3)
# Out:
#    absence_days                                  email
# 0             3         paul.casey.1@gslingacademy.com
# 1             2  danielle.sandoval.2@gslingacademy.com
# 2             9       tina.andrews.3@gslingacademy.com

# %%
#function in the dataframe - info(),describe() and other statistics method - mean(),median(),min(),prod(),sum()
df['math_score'].unique()
# Out:
# array([ 73,  90,  81,  71,  84,  93,  99,  95,  94,  98,  65,  80,  66,
#         96,  92,  86, 100,  57,  89,  50,  87,  64,  79,  82,  88,  70,
#         77,  85,  97,  54,  76,  91,  83,  62,  61,  51,  75,  60,  68,
#         78,  45,  43,  55,  69,  41,  49,  46,  63,  52,  59,  53,  44,
#         72,  74,  56,  48,  67,  42,  58,  40,  47], dtype=int64)

# %%
df2 = df.copy() #try to do copy so that original dataset can't be harmed.

# %%
df2['ujc_score']=list(range(1,2001)) #create new column & assign values.

# %%
df2.shape
# Out:
# (2000, 18)

# %%
df.corr() # find correlation of the values.
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_7344\1199355297.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr() # find correlation of the values.
#                                   id  part_time_job  absence_days  \
# id                          1.000000       0.012869     -0.017788
# part_time_job               0.012869       1.000000      0.206361
# absence_days               -0.017788       0.206361      1.000000
# extracurricular_activities -0.003121      -0.008382      0.029019
# weekly_self_study_hours     0.008524      -0.213963     -0.286086
# math_score                 -0.014042      -0.185573     -0.237072
# history_score               0.021959      -0.110774     -0.128159
# physics_score              -0.002003      -0.123929     -0.136419
# ...

# %%
df2 = df.drop(index = [0,3]) #deleting 2 rows in df2

# %%
df['physics_score'].mean() #same you able to find median(),max(),sum(),corr().
# Out:
# 81.3365

# %%
df.sort_values(by='math_score',ascending = True).tail(4)
# Out:
#         id first_name  last_name                                      email  \
# 1034  1035    Matthew     Potter      matthew.potter.1035@gslingacademy.com
# 1040  1041      Donna      Horne         donna.horne.1041@gslingacademy.com
# 960    961   Samantha  Alexander   samantha.alexander.961@gslingacademy.com
# 866    867  Stephanie  Hernandez  stephanie.hernandez.867@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# 1034    male           True             5                       False
# 1040  female          False             2                       False
# 960   female          False             4                       False
# 866   female          False             1                        True
#
#       weekly_self_study_hours career_aspiration  math_score  history_score  \
# 1034                       24    Stock Investor         100             80
# 1040                       34         Scientist         100             64
# ...

# %%
a = df2['math_score']<=55 #rows where score is low.
print(a)
# Out:
# 1       False
# 2       False
# 4       False
# 5       False
# 6       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998     True
# 1999    False
# Name: math_score, Length: 1998, dtype: bool

# %%
df[df["career_aspiration"]=="Scientist"] #extract that value in which career_aspiration is sceintist
# Out:
#         id   first_name  last_name  \
# 16      17        Vicki   Thompson
# 83      84      Charles     Butler
# 107    108     Benjamin      Morse
# 189    190        Sonia     Bowers
# 194    195     Angelica    Johnson
# 281    282        Jorge       Roth
# 311    312         Erik     Butler
# 312    313      Tiffany      Jones
# 387    388         John      Carey
# 429    430        David     Harris
# 530    531    Christina    Garrett
# 580    581    Christina   Guerrero
# 741    742      Breanna        Lee
# 766    767        April    Delgado
# 809    810      Brianna  Gutierrez
# 861    862        Brian      Adams
# 916    917          Lee   Campbell
# 977    978       Amanda  Hernandez
# 983    984       Daniel     Knight
# 1005  1006       Pamela      Green
# 1040  1041        Donna      Horne
# 1063  1064        James     Acosta
# 1074  1075        Grant      Mason
# 1090  1091      Brandon     Foster
# 1100  1101      Sabrina     Zavala
# ...

# %%
b= df[(df["career_aspiration"]=="Scientist") & df['math_score']<=55]
print(b)
# Out:
#         id first_name last_name                                    email  \
# 0        1       Paul     Casey           paul.casey.1@gslingacademy.com
# 1        2   Danielle  Sandoval    danielle.sandoval.2@gslingacademy.com
# 2        3       Tina   Andrews         tina.andrews.3@gslingacademy.com
# 3        4       Tara     Clark           tara.clark.4@gslingacademy.com
# 4        5    Anthony    Campos       anthony.campos.5@gslingacademy.com
# ...    ...        ...       ...                                      ...
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# ...

# %%
#df.loc[row_labels, column_labels], Label-based Location,Uses labels (strings or integers) to select rows and columns.
#df.ilocdf.iloc[row_indices, column_indices],Access data based on integer positions ,
df.iloc[7,4] #eight row, fifth column of a dataset
# Out:
# 'male'

# %%
df.iloc[3:5,[1]] #extract record of 2 column of 3,4 row.
# Out:
#   first_name
# 3       Tara
# 4    Anthony

# %%
df.loc[2] # it extract 3 row
# Out:
# id                                                           3
# first_name                                                Tina
# last_name                                              Andrews
# email                         tina.andrews.3@gslingacademy.com
# gender                                                  female
# part_time_job                                            False
# absence_days                                                 9
# extracurricular_activities                                True
# weekly_self_study_hours                                     13
# career_aspiration                           Government Officer
# math_score                                                  81
# history_score                                               97
# physics_score                                               95
# chemistry_score                                             96
# biology_score                                               65
# ...

# %%
df.loc[1:5,] #extract row 1 to 5
# Out:
#    id first_name last_name                                  email  gender  \
# 1   2   Danielle  Sandoval  danielle.sandoval.2@gslingacademy.com  female
# 2   3       Tina   Andrews       tina.andrews.3@gslingacademy.com  female
# 3   4       Tara     Clark         tara.clark.4@gslingacademy.com  female
# 4   5    Anthony    Campos     anthony.campos.5@gslingacademy.com    male
# 5   6      Kelly      Wade         kelly.wade.6@gslingacademy.com  female
#
#    part_time_job  absence_days  extracurricular_activities  \
# 1          False             2                       False
# 2          False             9                        True
# 3          False             5                       False
# 4          False             5                       False
# 5          False             2                       False
#
#    weekly_self_study_hours   career_aspiration  math_score  history_score  \
# 1                       47              Doctor          90             86
# ...

# %%
df.loc[[7],['first_name','last_name']] #retrive dataset for 7 row
# Out:
#   first_name last_name
# 7     George     Short

# %%
df['career_aspiration'].values
# Out:
# array(['Lawyer', 'Doctor', 'Government Officer', ..., 'Software Engineer',
#        'Business Owner', 'Accountant'], dtype=object)

# %%
df['career_aspiration'].values[3] #value of carrer aspiration of 3 row
# Out:
# 'Artist'

# %%
df['career_aspiration'].values[0:3]
# Out:
# array(['Lawyer', 'Doctor', 'Government Officer'], dtype=object)

# %%
df.values[3,1:4] # row basis
# Out:
# array(['Tara', 'Clark', 'tara.clark.4@gslingacademy.com'], dtype=object)

# %%
df.values[2:6,1] #column wise extract values
# Out:
# array(['Tina', 'Tara', 'Anthony', 'Kelly'], dtype=object)

# %%
"""Missing values are represent by NA(keyword),another missing values produced by numerical computation NaN(Not a number).impossble
value  are also represent by NaN"""
df.isnull().sum() # calculate the missing values of each column.
# Out:
# id                            0
# first_name                    0
# last_name                     0
# email                         0
# gender                        0
# part_time_job                 0
# absence_days                  0
# extracurricular_activities    0
# weekly_self_study_hours       0
# career_aspiration             0
# math_score                    0
# history_score                 0
# physics_score                 0
# chemistry_score               0
# biology_score                 0
# english_score                 0
# geography_score               0
# dtype: int64

# %%
df.dropna(inplace = True)  #delete complete observation row contains the missing value

# %%
#Imputation is the process to fill the missing values with the estimated ones. by fillna(value,inplace= True)
df['first_name'].fillna("ujj",inplace = True) # fill ujj in first_name column where null value presents.
df["math_score"].fillna(df['math_score'].mean(),inplace = True) # fill mean in math_score null value.

# %%
#delete dupicate value
df.duplicated().sum() #determine no of duplicate
# Out:
# 0

# %%
df.drop_duplicates() #remove duplicated entry from particular column.
# Out:
#         id first_name last_name                                    email  \
# 0        1       Paul     Casey           paul.casey.1@gslingacademy.com
# 1        2   Danielle  Sandoval    danielle.sandoval.2@gslingacademy.com
# 2        3       Tina   Andrews         tina.andrews.3@gslingacademy.com
# 3        4       Tara     Clark           tara.clark.4@gslingacademy.com
# 4        5    Anthony    Campos       anthony.campos.5@gslingacademy.com
# ...    ...        ...       ...                                      ...
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# ...

# %%
#data melting help to create different rows on basis of different value in different column.
df2.melt()
# Out:
#               variable value
# 0                   id     2
# 1                   id     3
# 2                   id     5
# 3                   id     6
# 4                   id     7
# ...                ...   ...
# 33961  geography_score    82
# 33962  geography_score    73
# 33963  geography_score    78
# 33964  geography_score    75
# 33965  geography_score   100
#
# [33966 rows x 2 columns]

# %%
name=pd.DataFrame ([['A', 'Van Heusen', '04-05-2021'], ['B', 'Nike', '10-06-2021'], ['D', 'Adidas', '21-07-2021'],

['E', 'Puma', '19-08-2021'], ['F', 'Gap', '26-09-2021']],

columns=['Brand', 'Name', 'Date'])
finaldata = pd.merge (df, pname, on=['math_score']) 
print (finaldata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[176], line 6
#       1 name=pd.DataFrame ([['A', 'Van Heusen', '04-05-2021'], ['B', 'Nike', '10-06-2021'], ['D', 'Adidas', '21-07-2021'],
#       2
#       3 ['E', 'Puma', '19-08-2021'], ['F', 'Gap', '26-09-2021']],
#       4
#       5 columns=['Brand', 'Name', 'Date'])
# ----> 6 finaldata = pd.merge (df, pname, on=['math_score'])
#       7 print (finaldata)
#
# NameError: name 'pname' is not defined
